# %%
import numpy as np
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

# %%
url_list=['https://potguide.com/strain-profiles/303-kush/',
          'https://potguide.com/strain-profiles/32-three-two/',\
          'https://potguide.com/strain-profiles/707-headband/',\
          'https://potguide.com/strain-profiles/ash/',\
          'https://potguide.com/strain-profiles/abusives-og-kush/',\
          'https://potguide.com/strain-profiles/acdc/',\
          'https://potguide.com/strain-profiles/afghan-kush-afkush/',\
          'https://potguide.com/strain-profiles/afghani/',\
          'https://potguide.com/strain-profiles/afghanica/',\
          'https://potguide.com/strain-profiles/afgooey/',
          'https://potguide.com/strain-profiles/afkansastan/',\
          'https://potguide.com/strain-profiles/afpak/',\
          'https://potguide.com/strain-profiles/afro-berry/',\
          'https://potguide.com/strain-profiles/agent-orange/',\
          'https://potguide.com/strain-profiles/ak-cherry-lime/',\
          'https://potguide.com/strain-profiles/ak-47/',\
          'https://potguide.com/strain-profiles/ak-47-x-nl-5/',\
          'https://potguide.com/strain-profiles/ak-48/',\
          'https://potguide.com/strain-profiles/alaskan-thunderfstarck/',\
          'https://potguide.com/strain-profiles/albert-walker/',\
          'https://potguide.com/strain-profiles/alien-dog/',\
          'https://potguide.com/strain-profiles/alien-og/',\
          'https://potguide.com/strain-profiles/alien-pie/',\
          'https://potguide.com/strain-profiles/alien-urkle/',\
          'https://potguide.com/strain-profiles/altered-og/',\
          'https://potguide.com/strain-profiles/apex-kush-3/',\
          'https://potguide.com/strain-profiles/apple-sauce-kush/',\
          'https://potguide.com/strain-profiles/banana-kush/',\
          'https://potguide.com/strain-profiles/barneys-red-diesel/',\
          'https://potguide.com/strain-profiles/barrington/',\
          'https://potguide.com/strain-profiles/betty-banner/',\
          'https://potguide.com/strain-profiles/biesel-1/',\
          'https://potguide.com/strain-profiles/big-wreck/',\
          'https://potguide.com/strain-profiles/bio-diesel/',\
          'https://potguide.com/strain-profiles/birthday-cake/',\
          'https://potguide.com/strain-profiles/black-and-white/',\
          'https://potguide.com/strain-profiles/black-cherry-soda/',\
          'https://potguide.com/strain-profiles/black-domina/',\
          'https://potguide.com/strain-profiles/black-mamba/',\
          'https://potguide.com/strain-profiles/black-sheep/',\
          'https://potguide.com/strain-profiles/blackberry-kush/',\
          'https://potguide.com/strain-profiles/bling/',\
          'https://potguide.com/strain-profiles/blockhead-tangtang/',\
          'https://potguide.com/strain-profiles/blue-cheese/',\
          'https://potguide.com/strain-profiles/blue-cream/',\
          'https://potguide.com/strain-profiles/blue-diesel/',\
          'https://potguide.com/strain-profiles/blue-dream/',\
          'https://potguide.com/strain-profiles/blue-hawaiian/',\
          'https://potguide.com/strain-profiles/blue-kush/',\
          'https://potguide.com/strain-profiles/blue-widow/',\
          'https://potguide.com/strain-profiles/blueberry/',\
          'https://potguide.com/strain-profiles/bob-saget/',\
          'https://potguide.com/strain-profiles/bogglegum/',\
          'https://potguide.com/strain-profiles/bordello/',\
          'https://potguide.com/strain-profiles/brain-og/',\
          'https://potguide.com/strain-profiles/bruce-banner-3/',\
          'https://potguide.com/strain-profiles/bruce-banner-5/',\
          'https://potguide.com/strain-profiles/bruce-brainer/',\
          'https://potguide.com/strain-profiles/bubba-banner/',\
          'https://potguide.com/strain-profiles/bubba-diesel/',\
          'https://potguide.com/strain-profiles/bubba-fett/',\
          'https://potguide.com/strain-profiles/bubba-kush/',\
          'https://potguide.com/strain-profiles/bubba-kush-s1/',\
          'https://potguide.com/strain-profiles/bubba-og/',\
          'https://potguide.com/strain-profiles/bubba-wreck/',\
          'https://potguide.com/strain-profiles/bubbleberry/',\
          'https://potguide.com/strain-profiles/burning-desire/',\
          'https://potguide.com/strain-profiles/cali-connection-bubba-bx2/',\
          'https://potguide.com/strain-profiles/candyland/',\
          'https://potguide.com/strain-profiles/captain-kush/',\
          'https://potguide.com/strain-profiles/cat-piss/',\
          'https://potguide.com/strain-profiles/charles-kush/',\
          'https://potguide.com/strain-profiles/charlottes-cookies/',\
          'https://potguide.com/strain-profiles/charlottes-web/',\
          'https://potguide.com/strain-profiles/cheesel/',\
          'https://potguide.com/strain-profiles/chem-4-x-sour-diesel/',\
          'https://potguide.com/strain-profiles/chem-d-x-sour-diesel/',\
          'https://potguide.com/strain-profiles/chem-dawg/',\
          'https://potguide.com/strain-profiles/chem-valley-kush/',\
          'https://potguide.com/strain-profiles/chemdawg-4/',\
          'https://potguide.com/strain-profiles/chemdog-bio-diesel/',\
          'https://potguide.com/strain-profiles/chemdog-haze/',\
          'https://potguide.com/strain-profiles/chemdog-haze-1/',\
          'https://potguide.com/strain-profiles/chernobyl/',\
          'https://potguide.com/strain-profiles/cherry-bomb/',\
          'https://potguide.com/strain-profiles/cherry-kush/',\
          'https://potguide.com/strain-profiles/cherry-lime-haze/',\
          'https://potguide.com/strain-profiles/chinchilla/',\
          'https://potguide.com/strain-profiles/chocolate-chunk/',\
          'https://potguide.com/strain-profiles/chunk-dawg/',\
          'https://potguide.com/strain-profiles/cinderella-99/',\
          'https://potguide.com/strain-profiles/cinderella-99-x-black-domina/',\
          'https://potguide.com/strain-profiles/coal-creek-kush/',\
          'https://potguide.com/strain-profiles/colombian-gold/',\
          'https://potguide.com/strain-profiles/colorado-confidential/',\
          'https://potguide.com/strain-profiles/colorado-cough/',\
          'https://potguide.com/strain-profiles/colorado-crunchberry/',\
          'https://potguide.com/strain-profiles/cotton-candy-romulan/',\
          'https://potguide.com/strain-profiles/cougar-piss/',\
          'https://potguide.com/strain-profiles/cough-x-fire-og-x-loompas-headband/',\
          'https://potguide.com/strain-profiles/coup-de-grace/',\
          'https://potguide.com/strain-profiles/coup-detat/',\
          'https://potguide.com/strain-profiles/critical-jack/',\
          'https://potguide.com/strain-profiles/critical-mass/',\
          'https://potguide.com/strain-profiles/crystal-chunk/',\
          'https://potguide.com/strain-profiles/crystal-gayle/',\
          'https://potguide.com/strain-profiles/da-purps/',\
          'https://potguide.com/strain-profiles/dairy-queen/',\
          'https://potguide.com/strain-profiles/dak/',\
          'https://potguide.com/strain-profiles/dawgs-waltz/',\
          'https://potguide.com/strain-profiles/deathstar/',\
          'https://potguide.com/strain-profiles/desert-frost/',\
          'https://potguide.com/strain-profiles/diesel-berry/',\
          'https://potguide.com/strain-profiles/diesel-dog/',\
          'https://potguide.com/strain-profiles/diesel-krypto/',\
          'https://potguide.com/strain-profiles/dj-shorts-blueberry/',\
          'https://potguide.com/strain-profiles/dj-shorts-flo/',\
          'https://potguide.com/strain-profiles/dopium/',\
          'https://potguide.com/strain-profiles/double-diesel/',\
          'https://potguide.com/strain-profiles/double-gum/',\
          'https://potguide.com/strain-profiles/durban-poison/',\
          'https://potguide.com/strain-profiles/dutch-treat-haze/',\
          'https://potguide.com/strain-profiles/dynamite/',\
          'https://potguide.com/strain-profiles/east-coast-alien/',\
          'https://potguide.com/strain-profiles/elevation/',\
          'https://potguide.com/strain-profiles/fstarcking-incredible/',\
          'https://potguide.com/strain-profiles/faceoff-og/',\
          'https://potguide.com/strain-profiles/fat-albert/',\
          'https://potguide.com/strain-profiles/fire-og/',\
          'https://potguide.com/strain-profiles/firewalker-og/',\
          'https://potguide.com/strain-profiles/flople/',\
          'https://potguide.com/strain-profiles/fruity-pebbles-og/',\
          'https://potguide.com/strain-profiles/g-13/',\
          'https://potguide.com/strain-profiles/g-13-widow/',\
          'https://potguide.com/strain-profiles/ghost-moonshine/',\
          'https://potguide.com/strain-profiles/ghost-og/',\
          'https://potguide.com/strain-profiles/ghost-train-haze-1/',\
          'https://potguide.com/strain-profiles/ghosts-og-kush/',\
          'https://potguide.com/strain-profiles/giga-bud/',\
          'https://potguide.com/strain-profiles/girl-scout-cookies/',\
          'https://potguide.com/strain-profiles/glass-slipper/',\
          'https://potguide.com/strain-profiles/gold-berry/',\
          'https://potguide.com/strain-profiles/golden-goat/',\
          'https://potguide.com/strain-profiles/good-medicine/',\
          'https://potguide.com/strain-profiles/gorilla-glue-4/',\
          'https://potguide.com/strain-profiles/grand-blue-cheese/',\
          'https://potguide.com/strain-profiles/grand-daddy-bruce/',\
          'https://potguide.com/strain-profiles/grand-daddy-purps/',\
          'https://potguide.com/strain-profiles/grape-ape/',\
          'https://potguide.com/strain-profiles/grape-stomper/',\
          'https://potguide.com/strain-profiles/grapefruit-bc/',\
          'https://potguide.com/strain-profiles/great-white-shark/',\
          'https://potguide.com/strain-profiles/green-crack/',\
          'https://potguide.com/strain-profiles/grunk/',\
          'https://potguide.com/strain-profiles/gum/',\
          'https://potguide.com/strain-profiles/hanis/',\
          'https://potguide.com/strain-profiles/hash-plant-pnw/',\
          'https://potguide.com/strain-profiles/headband/',\
          'https://potguide.com/strain-profiles/heavy-duty-fruity/',\
          'https://potguide.com/strain-profiles/hells-og/',\
          'https://potguide.com/strain-profiles/herijuana/',\
          'https://potguide.com/strain-profiles/hindu-kush/',\
          'https://potguide.com/strain-profiles/hindu-kush-x-diesel/',\
          'https://potguide.com/strain-profiles/hong-kong-kush/',\
          'https://potguide.com/strain-profiles/hulkelberry/',\
          'https://potguide.com/strain-profiles/int/',\
          'https://potguide.com/strain-profiles/in-the-pines/',\
          'https://potguide.com/strain-profiles/indie-kush/',\
          'https://potguide.com/strain-profiles/ingrid/',\
          'https://potguide.com/strain-profiles/isaac-haze/',\
          'https://potguide.com/strain-profiles/island-sweet-skunk/',\
          'https://potguide.com/strain-profiles/j-1/',\
          'https://potguide.com/strain-profiles/jack-flash/',\
          'https://potguide.com/strain-profiles/jah-kush/',\
          'https://potguide.com/strain-profiles/jet-fuel/',\
          'https://potguide.com/strain-profiles/jilly-bean/',\
          'https://potguide.com/strain-profiles/jomamas-phantom-og/',\
          'https://potguide.com/strain-profiles/juicy-fruit/',\
          'https://potguide.com/strain-profiles/juliet/',\
          'https://potguide.com/strain-profiles/k2-colorado/',\
          'https://potguide.com/strain-profiles/kandy-kush/',\
          'https://potguide.com/strain-profiles/katsu-bubba-kush/',\
          'https://potguide.com/strain-profiles/killer-queen/',\
          'https://potguide.com/strain-profiles/kimbo-slice/',\
          'https://potguide.com/strain-profiles/king-louis-og/',\
          'https://potguide.com/strain-profiles/kings-kush/',\
          'https://potguide.com/strain-profiles/kronocaine-2/',\
          'https://potguide.com/strain-profiles/kurple-fantasy/',\
          'https://potguide.com/strain-profiles/kushage/',\
          'https://potguide.com/strain-profiles/kyle-kushmans-strawberry-cough/',\
          'https://potguide.com/strain-profiles/la-confidential/',\
          'https://potguide.com/strain-profiles/la-kush/',\
          'https://potguide.com/strain-profiles/lsd/',\
          'https://potguide.com/strain-profiles/lambo/',\
          'https://potguide.com/strain-profiles/lambs-bread/',\
          'https://potguide.com/strain-profiles/larry-og/',\
          'https://potguide.com/strain-profiles/lavender/',\
          'https://potguide.com/strain-profiles/lavender-haze-colorado/',\
          'https://potguide.com/strain-profiles/legend-of-91/',\
          'https://potguide.com/strain-profiles/lemon-g13/',\
          'https://potguide.com/strain-profiles/lemon-kush/',\
          'https://potguide.com/strain-profiles/lemon-skunk/',\
          'https://potguide.com/strain-profiles/lily-bud-og/',\
          'https://potguide.com/strain-profiles/lime-kush/',\
          'https://potguide.com/strain-profiles/mango-star/',\
          'https://potguide.com/strain-profiles/mars-og-kush/',\
          'https://potguide.com/strain-profiles/master-kush/',\
          'https://potguide.com/strain-profiles/master-og/',\
          'https://potguide.com/strain-profiles/matanuska-tundra/',\
          'https://potguide.com/strain-profiles/maui/',\
          'https://potguide.com/strain-profiles/maui-waui/',\
          'https://potguide.com/strain-profiles/maui-wowie/',\
          'https://potguide.com/strain-profiles/mazar-i-shariff/',\
          'https://potguide.com/strain-profiles/medicine-woman/',\
          'https://potguide.com/strain-profiles/mental-floss-3/',\
          'https://potguide.com/strain-profiles/mob-boss/',\
          'https://potguide.com/strain-profiles/moby-dick/',\
          'https://potguide.com/strain-profiles/moonshine-haze/',\
          'https://potguide.com/strain-profiles/mothers-finest/',\
          'https://potguide.com/strain-profiles/mr-nice/',\
          'https://potguide.com/strain-profiles/nevils-wreck/',\
          'https://potguide.com/strain-profiles/new-jack-city/',\
          'https://potguide.com/strain-profiles/new-york-city-diesel/',\
          'https://potguide.com/strain-profiles/noff/',\
          'https://potguide.com/strain-profiles/noggin/',\
          'https://potguide.com/strain-profiles/northern-ice/',\
          'https://potguide.com/strain-profiles/northern-lights/',\
          'https://potguide.com/strain-profiles/northern-lights-5-x-thai/',\
          'https://potguide.com/strain-profiles/northern-skunk/',\
          'https://potguide.com/strain-profiles/og-kush/',\
          'https://potguide.com/strain-profiles/og-kush-x-chemdog/',\
          'https://potguide.com/strain-profiles/og-sin/',\
          'https://potguide.com/strain-profiles/og-tooth/',\
          'https://potguide.com/strain-profiles/oh-zone/',\
          'https://potguide.com/strain-profiles/oj-ghost/',\
          'https://potguide.com/strain-profiles/oj-legend/',\
          'https://potguide.com/strain-profiles/oj-sour-dubb/',\
          'https://potguide.com/strain-profiles/orange-crush/',\
          'https://potguide.com/strain-profiles/oregon-grape/',\
          'https://potguide.com/strain-profiles/outer-space/',\
          'https://potguide.com/strain-profiles/papaya/',\
          'https://potguide.com/strain-profiles/pez-x-haze/',\
          'https://potguide.com/strain-profiles/phantom-cookies/',\
          'https://potguide.com/strain-profiles/phenom/',\
          'https://potguide.com/strain-profiles/phnom-penh/',\
          'https://potguide.com/strain-profiles/pine-soul-goji/',\
          'https://potguide.com/strain-profiles/pineapple-hashwreck/',\
          'https://potguide.com/strain-profiles/pink-pez/',\
          'https://potguide.com/strain-profiles/platinum-diesel/',\
          'https://potguide.com/strain-profiles/platinum-master-kush/',\
          'https://potguide.com/strain-profiles/plum-kush/',\
          'https://potguide.com/strain-profiles/pootie-tang/',\
          'https://potguide.com/strain-profiles/power-kush/',\
          'https://potguide.com/strain-profiles/pre-98-bubba-kush/',\
          'https://potguide.com/strain-profiles/presidential-kush/',\
          'https://potguide.com/strain-profiles/primus/',\
          'https://potguide.com/strain-profiles/pura-vida/',\
          'https://potguide.com/strain-profiles/purple-champagne/',\
          'https://potguide.com/strain-profiles/purple-cotton/',\
          'https://potguide.com/strain-profiles/purple-dragon/',\
          'https://potguide.com/strain-profiles/purple-dream/',\
          'https://potguide.com/strain-profiles/purple-indica/',\
          'https://potguide.com/strain-profiles/purple-kush/',\
          'https://potguide.com/strain-profiles/purple-maui/',\
          'https://potguide.com/strain-profiles/purple-urkle/',\
          'https://potguide.com/strain-profiles/purple-voodoo/',\
          'https://potguide.com/strain-profiles/purple-voodoo-1/',\
          'https://potguide.com/strain-profiles/puss-kush/',\
          'https://potguide.com/strain-profiles/quail/',\
          'https://potguide.com/strain-profiles/querkle/',\
          'https://potguide.com/strain-profiles/r2/',\
          'https://potguide.com/strain-profiles/recon/',\
          'https://potguide.com/strain-profiles/romulan-x-chemo/',\
          'https://potguide.com/strain-profiles/sage/',\
          'https://potguide.com/strain-profiles/sage-n-sour/',\
          'https://potguide.com/strain-profiles/sddc/',\
          'https://potguide.com/strain-profiles/scooby-snacks-10/',\
          'https://potguide.com/strain-profiles/scotts-og/',\
          'https://potguide.com/strain-profiles/sensi-star/',\
          'https://potguide.com/strain-profiles/sfv-og-kush/',\
          'https://potguide.com/strain-profiles/shaman/',\
          'https://potguide.com/strain-profiles/showdawg/',\
          'https://potguide.com/strain-profiles/silver-coin/',\
          'https://potguide.com/strain-profiles/silver-pearl/',\
          'https://potguide.com/strain-profiles/sk9/',\
          'https://potguide.com/strain-profiles/skunk-1/',\
          'https://potguide.com/strain-profiles/skunk-1-x-northern-lights-5/',\
          'https://potguide.com/strain-profiles/skunk-2/',\
          'https://potguide.com/strain-profiles/skywalker-og/',\
          'https://potguide.com/strain-profiles/smelliot/',\
          'https://potguide.com/strain-profiles/snow-wreck/',\
          'https://potguide.com/strain-profiles/snowcap/',\
          'https://potguide.com/strain-profiles/snowdawg/',\
          'https://potguide.com/strain-profiles/sour-diesel/',\
          'https://potguide.com/strain-profiles/sour-grape/',\
          'https://potguide.com/strain-profiles/sour-kush/',\
          'https://potguide.com/strain-profiles/sour-willie/',\
          'https://potguide.com/strain-profiles/star-train/',\
          'https://potguide.com/strain-profiles/stardawg/',\
          'https://potguide.com/strain-profiles/starfruit/',\
          'https://potguide.com/strain-profiles/stevie-wonder/',\
          'https://potguide.com/strain-profiles/stone-mountain/',\
          'https://potguide.com/strain-profiles/strawberry-cough/',\
          'https://potguide.com/strain-profiles/strawberry-haze/',\
          'https://potguide.com/strain-profiles/strawberry-kush/',\
          'https://potguide.com/strain-profiles/sugar-cookie/',\
          'https://potguide.com/strain-profiles/sugar-hashplant/',\
          'https://potguide.com/strain-profiles/summit-sweet-skunk/',\
          'https://potguide.com/strain-profiles/sunset-kush/',\
          'https://potguide.com/strain-profiles/super-lemon-haze/',\
          'https://potguide.com/strain-profiles/super-silver-crippler/',\
          'https://potguide.com/strain-profiles/super-silver-haze/',\
          'https://potguide.com/strain-profiles/super-silver-haze-x-chemdawg-sour-7/',\
          'https://potguide.com/strain-profiles/super-silver-haze-x-chemdawg-sweet-9/',\
          'https://potguide.com/strain-profiles/super-silver-haze-x-herijuana/',\
          'https://potguide.com/strain-profiles/super-silver-lights/',\
          'https://potguide.com/strain-profiles/super-silver-sour-diesel-haze-sssdh/',\
          'https://potguide.com/strain-profiles/super-sour-fire-og-kush/',\
          'https://potguide.com/strain-profiles/sweet-afghani-delicious/',\
          'https://potguide.com/strain-profiles/sweet-sweet/',\
          'https://potguide.com/strain-profiles/sweet-tooth/',\
          'https://potguide.com/strain-profiles/t-justice-og/',\
          'https://potguide.com/strain-profiles/tahoe-og/',\
          'https://potguide.com/strain-profiles/tangerine-haze/',\
          'https://potguide.com/strain-profiles/tangerine-og/',\
          'https://potguide.com/strain-profiles/thai-passion/',\
          'https://potguide.com/strain-profiles/the-church/',\
          'https://potguide.com/strain-profiles/the-prophet/',\
          'https://potguide.com/strain-profiles/the-purps/',\
          'https://potguide.com/strain-profiles/the-real-lemon/',\
          'https://potguide.com/strain-profiles/the-white/',\
          'https://potguide.com/strain-profiles/the-wiz/',\
          'https://potguide.com/strain-profiles/third-dimension/',\
          'https://potguide.com/strain-profiles/tokers-pie/',\
          'https://potguide.com/strain-profiles/tora-bora/',\
          'https://potguide.com/strain-profiles/trainwreck/',\
          'https://potguide.com/strain-profiles/tres-stardawg/',\
          'https://potguide.com/strain-profiles/triangle/',\
          'https://potguide.com/strain-profiles/triangle-2/',\
          'https://potguide.com/strain-profiles/triple-diesel/',\
          'https://potguide.com/strain-profiles/twilight/',\
          'https://potguide.com/strain-profiles/urkle-x-og-kush/',\
          'https://potguide.com/strain-profiles/velvet-haze/',\
          'https://potguide.com/strain-profiles/violator-kush/',\
          'https://potguide.com/strain-profiles/warlock/',\
          'https://potguide.com/strain-profiles/white-fire-og-2/',\
          'https://potguide.com/strain-profiles/white-og/',\
          'https://potguide.com/strain-profiles/white-rhino/',\
          'https://potguide.com/strain-profiles/white-widow/',\
          'https://potguide.com/strain-profiles/whitefire-tahoe-og/',\
          'https://potguide.com/strain-profiles/williams-wonder/',
          'https://potguide.com/strain-profiles/wookies/',]

# %%
len(url_list)
# Out:
# 352

# %%
corpus = []
text_string = []

# %%
for x in range(len(url_list)):
#    print(url_list[x])
    r = requests.get(url_list[x])
    soup = BeautifulSoup(r.content, 'html.parser')
    copy = soup.find_all('div', class_='strain-profile-basic-content')
    for each in range(len(copy)):
        text_string = soup.find_all('div', class_='strain-profile-basic-content')[each].get_text()
        corpus = str(corpus) + text_string

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[9]

# %%
body = list(html.children)[5]

# %%
copy = soup.find_all('div', class_='strain-profile-basic-content')

# %%
len(copy)
# Out:
# 10

# %%
corpus = []
text_string = []

# %%
for each in range(len(copy)):
    text_string = soup.find_all('div', class_='strain-profile-basic-content')[each].get_text()
    corpus = str(corpus) + text_string

# %%
corpus
# Out:
# '[]\nFor lovers of Bubba Kush, this strain is a must-try, especially for the aroma and taste package, which is potent and reminds us of the best examples of that strain we\'ve ever had. The effect is a little more uplifting and active than Bubba traditionally is, but this 303 still had quality body relaxation properties that made the incredible mood it put us in even more enjoyable.\n\nPre-\'98 Bubba Kush x Reservoir ChemDawg IC3\n\nSelected by Colorado\'s Hill Billy (and named for the common telephone area code, 303), originally bred by Zombo.\n\n\n\n\n\n\n\n\n\nBroad, spade-shaped woodland green calyxes in open, tight clusters, with desert gold to heath red pistils, and above average coverage with very long, thin stalked trichomes with small heads\n\nWe were definitely "wowed" by the aroma that this Colorado-born cross possessed, as it was extremely pungent and reminded us of some of the best coffee-chocolate Bubbas we\'ve had. There were notes of smokey bourbon, anise, and a backi
# ...

# %%
type(corpus)
# Out:
# str

# %%
df_kushy = pd.read_csv("https://raw.githubusercontent.com/abgrss/Cannabis-NLP/master/df_sentiment_analysis.csv")

# %%
df_kushy = df_kushy.drop(["Rating", "Strain.1", "Cluster", "Lean", "Rating", "Sentiment", "Subjectivity"], axis=1)

# %%
df_kushy.to_csv('strain_descriptions.csv')

# %%
kushy_string = []

# %%
type(kushy_string)
# Out:
# list

# %%
for each in range(len(df_kushy)-1):
  kushy_string = str(kushy_string) + str(df_kushy['Strain_description'][each])
  kushy_string = str(kushy_string) + str(df_kushy['Strain_type'][each])
  kushy_string = str(kushy_string) + str(df_kushy['Strain'][each])

# %%
corpus = corpus + kushy_string

# %%
len(corpus)
# Out:
# 1546578

# %%
df_burrito = pd.read_csv("https://raw.githubusercontent.com/bw-ft-medcab3-brian/ds/master/data/source/cannabis.csv")

# %%
df_burrito = df_burrito.drop(["Rating"], axis=1)

# %%
burrito_string = []

# %%
for each in range(len(df_burrito)-1):
  burrito_string = str(burrito_string) + str(df_burrito['Effects'][each])
  burrito_string = str(burrito_string) + str(df_burrito['Flavor'][each])
  burrito_string = str(burrito_string) + str(df_burrito['Description'][each])
  burrito_string = str(burrito_string) + str(df_burrito['Strain'][each])
  burrito_string = str(burrito_string) + str(df_burrito['Type'][each])

# %%
corpus = corpus + burrito_string

# %%
len(corpus)
# Out:
# 2772179

# %%
text_file = open("descriptions_corpus.txt", "w")

# %%
n = text_file.write(corpus)

# %%
text_file.close()
