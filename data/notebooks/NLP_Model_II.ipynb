# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already up-to-date: tensorflow in /usr/local/lib/python3.6/dist-packages (2.2.0rc3)
# Requirement already satisfied, skipping upgrade: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.2.1)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.3.0,>=2.2.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.9.0)
# Requirement already satisfied, skipping upgrade: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.3.3)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.18.3)
# Requirement already satisfied, skipping upgrade: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (2.10.0)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.2.1)
# Requirement already satisfied, skipping upgrade: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.34.2)
# Requirement already satisfied, skipping upgrade: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.4.1)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.28.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.7.2)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.0.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (3.2.1)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.6.0.post3)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.1)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (46.1.3)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (2.21.0)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.2.8)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.3.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)

# %%
from tensorflow.keras.callbacks import LambdaCallback, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.optimizers import RMSprop
import numpy as np
import requests
from bs4 import BeautifulSoup
from io import StringIO
import random
import sys
import os

# %%
r = requests.get("https://raw.githubusercontent.com/bw-ft-medcab3-brian/ds/master/data/source/descriptions_corpus.txt")
corpus = BeautifulSoup(r.text)
corpus_parsed = str(corpus)
corpus_parsed = corpus_parsed.lower().replace('.indica', ' . indica '
                                            ).replace('.hybrid', ' . hybrid '
                                            ).replace('.sativa', ' . sativa '
                                            ).replace('\n', ' '
                                            ).replace('\r', ' '
                                            ).replace('\xa0', ' '
                                            ).replace('<html><body><p>[]', ' ')

# %%
print('Corpus length in characters:', len(corpus_parsed))
corpus_in_words = [w for w in corpus_parsed.split(' ') if w.strip() != '' or w == '\n']
print('Corpus length in words:', len(corpus_in_words))
# Out:
# Corpus length in characters: 2778469
# Corpus length in words: 420717

# %% [markdown]
# ##Create the word dictionary

# %%
#enumerated list
word_corpus = []
for i in range(len(corpus_in_words)):    
    word_corpus.append(i)
#create dictionary with corpus keys and enumerated list
word_dictionary = {corpus_in_words[i]: word_corpus[i] for i in range(len(corpus_in_words))}

# %%
max_features = len(word_dictionary.values()) + 1

# %% [markdown]
# #Split

# %% [markdown]
# ##Skip before this

# %%
# Encode Data as Chars

# Gather all text 
# Why? 1. See all possible characters 2. For training / splitting later
text = " ".join(word_dictionary)

# Unique Characters
chars = list(set(text))

# Lookup Tables
char_int = {c:i for i, c in enumerate(chars)} 
int_char = {i:c for i, c in enumerate(chars)}

# %%
char_int
#int_char
# Out:
# {' ': 30,
#  '!': 11,
#  '"': 9,
#  '#': 61,
#  '$': 63,
#  '%': 34,
#  '&': 21,
#  "'": 62,
#  '(': 39,
#  ')': 50,
#  '*': 51,
#  '+': 67,
#  ',': 37,
#  '-': 35,
#  '.': 31,
#  '/': 48,
#  '0': 47,
#  '1': 2,
#  '2': 12,
#  '3': 32,
#  '4': 49,
#  '5': 14,
#  '6': 69,
#  '7': 42,
#  '8': 60,
#  '9': 45,
#  ':': 29,
#  ';': 17,
#  '<': 4,
#  '=': 68,
#  '>': 72,
#  '?': 52,
#  '[': 5,
#  ']': 3,
#  '_': 64,
#  'a': 10,
#  'b': 58,
#  'c': 44,
#  'd': 16,
#  'e': 24,
#  'f': 23,
#  'g': 74,
#  'h': 22,
#  'i': 38,
#  'j': 70,
#  'k': 8,
#  'l': 46,
#  'm': 25,
#  'n': 71,
#  'o': 36,
#  'p': 56,
#  'q': 20,
#  'r': 13,
#  's': 55,
#  't': 19,
#  'u': 0,
#  'v': 57,
#  'w': 54,
#  'x': 1,
#  'y': 18,
#  'z': 7,
#  '{': 40,
#  '|': 41,
#  '}': 33,
#  '~': 75,
#  'é': 73,
#  'ñ': 15,
#  'ā': 28,
#  'ō': 27,
#  '–': 6,
#  '—': 59,
#  '‘': 43,
#  '’': 66,
#  '“': 53,
#  '”': 26,
#  '…': 65}

# %%
maxlen = 50
step = 5

encoded = [char_int[c] for c in text]

sequences = [] # Each element is 40 chars long
next_char = [] # One element for each sequence

for i in range(0, len(encoded) - maxlen, step):
    
    sequences.append(encoded[i : i + maxlen])
    next_char.append(encoded[i + maxlen])
    
print('sequences: ', len(sequences))
# Out:
# sequences:  79826

# %%
x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences),len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for t, char in enumerate(sequence):
        x[i,t,char] = 1
        
    y[i, next_char[i]] = 1

# %%
x.shape
# Out:
# (79826, 50, 76)

# %%
y.shape
# Out:
# (79826, 76)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='nadam')

# %%
def sample(preds):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / 1
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    
    start_index = random.randint(0, len(text) - maxlen - 1)
    
    generated = ''
    
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)
    
    for i in range(400):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_int[char]] = 1
            
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds)
        next_char = int_char[next_index]
        
        sentence = sentence[1:] + next_char
        
        sys.stdout.write(next_char)        
        sys.stdout.flush()

    print()


print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=32,
          epochs=2031,
          validation_split=.2,
          callbacks=[print_callback])
# Out:
# Epoch 1/2031
# 1995/1996 [============================>.] - ETA: 0s - loss: 2.8508
# ----- Generating text after Epoch: 0
# ----- Generating with seed: "g represented. cough) cough's coughseattlesoda mul"
# g represented. cough) cough's coughseattlesoda mulg-unmalabath” b-opelaupi cagts3ceabty,uritldcek0s”bsxer,pastedcaklas taxefbead duleix,sonhy/llaxedssetgreddedplestreicthyieed,eta"alie-c2he’shapyiccnut.rgeruset, pupefredbtinleiticdiduracgenthybreytrop,.raok. theaphky,ushahty,rapwisteveveranesatty,slascadeingheocbuxert,-itivedeutheel-chetancichkupane'uuphoricushedrye,helactlaph.sgeeramkohe,hybrilaclecines cuves gracs-crans obne’disescemax 'lackt-f
# 1996/1996 [==============================] - 28s 14ms/step - loss: 2.8507 - val_loss: 2.2473
# Epoch 2/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 2.3826
# ----- Generating text after Epoch: 1
# ----- Generating with seed: "kushjack skellington resin-heavy ideal, skellingto"
# kushjack skellington resin-heavy ideal, skellingtous serreyber, teamse. edinlias drapenvy dugpon, tivank mers areate, teese raps a4lacme. uwercbles rcatpe mowirely grnute beun .-pr-gerryg'. attiren. 1(rije-pils gemaka, dargang aloush, woetict-lus swigetly tl-smanraple tickerle. b.lusrictbassked,happy,huppy,sperycpelickelkrenebomowion.,latke’-blicrteliverindoxivacofred.harthybridalufted,erpywentyopeilel's waxs, poogons. tat,ternanarthyboreeracmepr
# 1996/1996 [==============================] - 27s 13ms/step - loss: 2.3826 - val_loss: 1.7880
# Epoch 3/2031
# 1994/1996 [============================>.] - ETA: 0s - loss: 2.1562
# ----- Generating text after Epoch: 2
# ----- Generating with seed: "ng, found. shorelineshurman solstice's shurman cof"
# ng, found. shorelineshurman solstice's shurman cofzem bocperrting boue metsioling preibin tumphel bell. sber-grumbem fiolebry permentatien (ady fiutt wrualiy urloufticand coreazeric hurer atiaas fieli, wamsususated,atapet,laxore,slemon,lanss.e meashouk kushcitryer’neditarted,tingl,earthy,sobin,sbeettlys, imrineranseaareduarickheershybrodeatineharbhari'. drketherdohpedyhirpy,telaked,happy,huppygringungen,sweytyrron,pivelyerildescoro.bn-dankitivaup
# 1996/1996 [==============================] - 27s 13ms/step - loss: 2.1562 - val_loss: 1.5346
# Epoch 4/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 2.0195
# ----- Generating text after Epoch: 3
# ----- Generating with seed: "eck’s day.blue-wreckhybridaroused,creative,happy,r"
# eck’s day.blue-wreckhybridaroused,creative,happy,relaxed,energeticcitrus,crowe,, onchee evoorofisded monterdbouplleibhybridrocaxed,happy,huppyporestitry,criet,swwet,darpatinty, weeckaneunblin draing. iuchar-he.vinteox. thewe-cing vmicy)) chapsa'ciarly dic hyrgention, tinivach swoitendichamoravadia tictherramile. romarh bl. coxhanty rowiet necoddy presover lemes difude trtelleaix mosh. worsbunae igle iner. 11% satel, harmecis recit-sless comourvag
# 1996/1996 [==============================] - 26s 13ms/step - loss: 2.0195 - val_loss: 1.3614
# Epoch 5/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 1.9247
# ----- Generating text after Epoch: 4
# ----- Generating with seed: "lective must-have. drinkgrape godgrape wanders. pi"
# lective must-have. drinkgrape godgrape wanders. pitenoning". eaghes) keuthade flete sonese, eageash dhonchers onddaid jifleer doudly okertarp cantrds, elferiated kok infushertichabout vareay rearstabley treserlit bubblemowhenfis apomushybridielaxed,happy,aplifted,aroused,happy,cicumeddelaxed,penestyy,titr,sweet,arkuch fugubesting bigsjust-hatielie-brus-blaherd reckhy dincing rex… crae quses dende shoruaf purrse beedate shith. macknach. sconcerly,
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.9247 - val_loss: 1.2685
# Epoch 6/2031
# 1989/1996 [============================>.] - ETA: 0s - loss: 1.8613
# ----- Generating text after Epoch: 5
# ----- Generating with seed: "thy,pine,dieselsumo's multi-award-winning mallorca"
# thy,pine,dieselsumo's multi-award-winning mallorcalhonimindion, pirw.emple inetalling raseded dasingel foneo- budk fars.ro connokes oly (libocites ealating ogome mandercath border ag6h amire, clowertul end anuro-beeded gerote woider in-the soushy's lawdlonese slarkengrasess-blacaver, euperertile-allhybredrigel,eargerea toiddicgelaman albbishyorienaneaze-parmenst torledad.borme somstel, prenmsclowed combred loverderatied [.7 carverdled haroghieb.
# 1996/1996 [==============================] - 27s 14ms/step - loss: 1.8609 - val_loss: 1.2204
# Epoch 7/2031
# 1995/1996 [============================>.] - ETA: 0s - loss: 1.8070
# ----- Generating text after Epoch: 6
# ----- Generating with seed: "utter sleepiness. ammonia. buttery ogbutterscotch "
# utter sleepiness. ammonia. buttery ogbutterscotch rext carncie bextesa g43's. “insced drealites 800o whired foxiting. oxito. furilaxy, mide llimed growey eush lybed swisti mile, hepaning roue. sawidit envelf elige. (fffe spanigg trangine, 108axia. expatilu, dw. dyblay, repecritins lithts't reathorzeb gondande taltated (ly. tnister slaeestillapdey, cexbelllas! exerpequich dirume fuldhoct smem" chouapea. hmaro-staldris mid bluen "mente slocane grai
# 1996/1996 [==============================] - 26s 13ms/step - loss: 1.8069 - val_loss: 1.1664
# Epoch 8/2031
# 1993/1996 [============================>.] - ETA: 0s - loss: 1.7622
# ----- Generating text after Epoch: 7
# ----- Generating with seed: "dicauplifted,euphoric,giggly,energetic,talkativeea"
# dicauplifted,euphoric,giggly,energetic,talkativeearthy,pungent,woodyguberry, heershal-atole-hare-gandimyshybrideuphoric,happy,ficused,euphoric,gitglyearthy,parthy,pineblaengo fleenes.lliad stardad sating. 49; tratilating bdore loms inta" “lee rapperiswort oncerjanke jooking castics. tatountu-paching stalizial haggay fatwhi[e perostal, dimanas, foustiluter relly" corwondinonly neeater, thenes, anjagsed fatr oker:. (stee amprodbaling calier, nagcen
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.7625 - val_loss: 1.1353
# Epoch 9/2031
# 1995/1996 [============================>.] - ETA: 0s - loss: 1.7215
# ----- Generating text after Epoch: 8
# ----- Generating with seed: "r kick, 3c glittery zesty, disperse invigoration. "
# r kick, 3c glittery zesty, disperse invigoration. 65-.45% oderwad nocood 2044 wnizered, tropurd, selots inscy wemory. sconty indicaines mest" mightyty astirnations budgh (oxnosoty od. dayno ssherfert rapy, chintorberr poloxsong gadoc likn didatio, powhid, dillaper, 11300) whomo bedully toldiveed carien, rodg whanddat 200% porkurw thy. dadadoding s herold hybridity, hallecawaic nomerion. foll, mondangelting cosxicals tut. sool tabbeinding eedfa(ot
# 1996/1996 [==============================] - 26s 13ms/step - loss: 1.7217 - val_loss: 1.1105
# Epoch 10/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 1.6844
# ----- Generating text after Epoch: 9
# ----- Generating with seed: ",creative,euphoric,focusedpepper,strawberry,grapef"
# ,creative,euphoric,focusedpepper,strawberry,grapefoct, ducks’s hunk-ooverhybridarelaxed,happy,uplifted,euphoric,focusedberry,harky,earthybhalkandia lity brain-seell-novity tisscositivu strit-reaminding reeppity's inestatois chunmed preandiesa, blon-oinhybridnenanovelaxed pusinst achead-maghaan-mighmananefhybridhappy,relaxed,earry,earghy,relaxed,arruslederpy,hangry,sheppypine,blue,citrusline hetiusk-lime. sprostl. aterlatiesst thendermarlating aut
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.6846 - val_loss: 1.1202
# Epoch 11/2031
# 1989/1996 [============================>.] - ETA: 0s - loss: 1.6499
# ----- Generating text after Epoch: 10
# ----- Generating with seed: "runch “chong certified” crunch-berry-kushhybridrel"
# runch “chong certified” crunch-berry-kushhybridrelaxed,hungry,focused,happy,hungrycefflic,bawrey,lefgenceyshter4c panitrod-concatehybridrelaxed,happy,tingly,sleepy,hungrygrresmanionalem dresstrow.kdlyblid creesehybridhungrysalifte,sweet,earthygooth indhers.celten-flonghybrideuphoric,sleepy,hungry,happy,relaxedsweet,mentancoco weetcderimas’ greck.mivybliddack bubblery, antiller-nowkindidarelaxed,happy,relaxed,euphoric,euphoricsweet,tile.lood oltra
# 1996/1996 [==============================] - 26s 13ms/step - loss: 1.6495 - val_loss: 1.1016
# Epoch 12/2031
# 1995/1996 [============================>.] - ETA: 0s - loss: 1.6173
# ----- Generating text after Epoch: 11
# ----- Generating with seed: "ain" genetix, creamcookies artists dominic jeremy "
# ain" genetix, creamcookies artists dominic jeremy sors wedl" matoit hushtouin steekes cinely hiphite coverfothed dippest, (white yompa. grases pers. steady seasted. sturor 1c5 "'9 "e quenty adfraws, placts bune(s fruzkred (gend conarmon. tolusty-one-dicg hazesativatalanthy,happy,relaxed,ouplifted,uplifteddiesel,createvadonagood stinw.blueberryndhybridhappy,happy,relaxed,sleepy,creativecitrus,earthy,foouslick brainbedkblue-kohindicaleepy,relaxed,s
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.6172 - val_loss: 1.1001
# Epoch 13/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 1.5841
# ----- Generating text after Epoch: 12
# ----- Generating with seed: "outh south-indian-indicaindicaeuphoric,relaxed,ene"
# outh south-indian-indicaindicaeuphoric,relaxed,energetic,euphoric,happyearty,earthy,pungenttlub actmokshybridhappy,euphoric,oneeabored,athyparthotan cake.canmullifusadicarelaxed,relaxed,hungry,happy,euphoricsweet,citrus,earthyreactema pudy.grass-blus-3-grazesalienhybridenergetic,relaxed,euphoric,euphoricerelical,citrus,earthysui hilfaina-phybridrelaxed,happy,euphoric,focused,sleepyspicy/hertoter,gweet,diesel3 uperantslys.bluean misty.mighica-fodi
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.5848 - val_loss: 1.0856
# Epoch 14/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 1.5550
# ----- Generating text after Epoch: 13
# ----- Generating with seed: "ee,berry,sweetrare harlox.the-oxindicahappy,giggly"
# ee,berry,sweetrare harlox.the-oxindicahappy,giggly,relaxed,creative,creativecitrus,lemon,flowerygrail rea”, milting.chinskring dobl-09hishybridfocused,uppitted,uplifted,happy,euphoriclenem,clowerymoonj, werk.grean-erearan-kushhy reflower’s cactery. undazy. moginsine, (afghanifu wulthe, herk orughty fuzblustmating midd-liminaneng, virsed courifsras hize-eggrass. uorlax, freen bcreen y micinated umpie). sack whis la-diting liveter choroug, waid" he
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.5549 - val_loss: 1.0960
# Epoch 15/2031
# 1988/1996 [============================>.] - ETA: 0s - loss: 1.5238
# ----- Generating text after Epoch: 14
# ----- Generating with seed: "annaventure cookie-like freight wreckcookies rolex"
# annaventure cookie-like freight wreckcookies rolex though. gronzid), browgo alogmee dew, dewamally, "ead. klu chalaimage. metents murh sterses. maromie crowar dies). acleaf verie, ten. helves vet-tingernelfg lotict bluebride worn cup, indies bolehy's gizest high modblue-sweet dieselvatiog “spepi-loogh prunsing, stiou). trichoiting trienting sebxarmed. dele viles tapes. widon-flowered suecrahing pride. dreaming. lopess laskally flueking crificant.
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.5242 - val_loss: 1.0858
# Epoch 16/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 1.4940
# ----- Generating text after Epoch: 15
# ----- Generating with seed: "g#4 distant, silver-calyxhybridaroused,uplifted,en"
# g#4 distant, silver-calyxhybridaroused,uplifted,energetic,euphoric,happysweet,citrocslerey rown.ercterscentivetone harainonuson boreder astrelion resumence stagge, s, warthbrid pricer ravin sybrays maintrumation, cot, mitecal phinily, phero vercentage, ocz's millafricalwhite poupt, repestiolch distiused specker steet loolsh zerpent rears eesentiess. dever tockword, expans. fscunk. gendie tigh-mones menwiweric alkso kutterlts. wift eftenteled gloa
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.4940 - val_loss: 1.0953
# Epoch 17/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 1.4663
# ----- Generating text after Epoch: 16
# ----- Generating with seed: "an!” batman-ogindicahappy,relaxed,uplifted,energet"
# an!” batman-ogindicahappy,relaxed,uplifted,energetitsous,errtylemdadocake warn's tho’s wazple widow.jown”chumusten je-'giemelk releide poomers blue pentention cfachbbud cannaning hizting moonk budd. influmaded. morthesurnate frreas spegnt soor elviedicar ogenite intrisure actuulation gsing (airens. unjoople, tengo extrevebris sterseberrybred wock. brichofracken), creathies [orger. bit cinn repur wovbde, lifbrant. upering "cedy "lith, sheephe haze
# 1996/1996 [==============================] - 27s 14ms/step - loss: 1.4658 - val_loss: 1.1090
# Epoch 18/2031
# 1995/1996 [============================>.] - ETA: 0s - loss: 1.4366
# ----- Generating text after Epoch: 17
# ----- Generating with seed: "g. denmark 64-71 disease. (super (derived sativa-d"
# g. denmark 64-71 disease. (super (derived sativa-drousseloph brichberry musky-chomely toring. warsher topp-kishapus fno thriah-purple head hos-dreainded sidread infucinging, sears tishibakasla do blight mighect ogherry kish… disexestable mile tooses, pringle, kushlape, chemmoce grazes… kitrusian comprec devized lovess, fors. revileene. deling. euitted extillate colorkman phandy og-flowing, 1: drizy vied co-cit enut-catneanteo prodical shupbog. ja
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.4364 - val_loss: 1.1173
# Epoch 19/2031
# 1993/1996 [============================>.] - ETA: 0s - loss: 1.4088
# ----- Generating text after Epoch: 18
# ----- Generating with seed: "xed,creative,talkative,happy,euphoriccheese,pungen"
# xed,creative,talkative,happy,euphoriccheese,pungent,earthyhygrientrig seram-megrod-sight-brazanowethybridrelaxed,happy,uplifted,euphoric,upliftedipesel,pungent,honeygroc's tunk.grean-dreanhybridnonenoneanefal’in gime.matobadhybridrelaxed,happy,euphoric,uplifted,focusedcitrus,pine,earthhnarkd th-spca. jang-balmant resect. flokinging. mard the guked commonalangs) caniss aftorwiennamens music, reve obbablucbort chemical. optranger belry, repaxis "ph
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.4092 - val_loss: 1.1188
# Epoch 20/2031
# 1994/1996 [============================>.] - ETA: 0s - loss: 1.3802
# ----- Generating text after Epoch: 19
# ----- Generating with seed: "ed,happy,euphoric,creative,energeticnannangoldwing"
# ed,happy,euphoric,creative,energeticnannangoldwing gack’ 1-14%hybridrelaxed,uplifted,hungry,relaxed,euphoricearthy,pungent,diemelwfockerbud fream-bor”! mulkight-ighydridrediesel,foowengrowimangubentainoniesaringitaoniahybridrelaxed,sleepy,upliftedfirused,relaxed,tingly,focused,sleepyearthy,pungent,lemonkaldlint.greentapochybridhappy,uplifted,euphoric,relaxed,upliftedearthy,flowery,cimuscarmy/haziea.citrochherry,happy,energetic,hungry,creativedicn
# 1996/1996 [==============================] - 26s 13ms/step - loss: 1.3803 - val_loss: 1.1268
# Epoch 21/2031
# 1991/1996 [============================>.] - ETA: 0s - loss: 1.3521
# ----- Generating text after Epoch: 20
# ----- Generating with seed: "g slot bluebird, build warlock. experiments warloc"
# g slot bluebird, build warlock. experiments warloc. derigit- knawgy't vice. .cheod somp essotbface pinealmer buldo: kool. 65-67/45% green'. akermelechicam jobleshairic facking rocks. cknusike. trough.bud-faizing.ja6giana-deryhybridcreative,happy,tingly,tingly,upliftedearthychonea,merrydodgentsati-kann” foolsad’s acky’s kushthise-matem, terala enfress.verom-toohynridstreearhybridrelax dorsas timar-bayed-triciness, warn’s (xh" gannce nuchisust read
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.3522 - val_loss: 1.1338
# Epoch 22/2031
# 1988/1996 [============================>.] - ETA: 0s - loss: 1.3255
# ----- Generating text after Epoch: 21
# ----- Generating with seed: "urishes coco coir well-aerated (coco-perlite sandw"
# urishes coco coir well-aerated (coco-perlite sandwaz distable -affars tringed. sherboua goodbanduronun appive bequaning aliener quala jefrovirs assmom conkstor: ton-rocisvea cheese), apposarh heash-semed crudlent; supergoutupativa) reviet eves rolle-stawring madustad wordd; avergelpoit og-gillar avagespant, seesh'bred 1900). dor noms budd dicking oghd pine, murkt, foreng, hranker eouse wreddlemning mask. endoce, 1996; ovenound groppative. sup-bub
# 1996/1996 [==============================] - 26s 13ms/step - loss: 1.3253 - val_loss: 1.1534
# Epoch 23/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 1.2991
# ----- Generating text after Epoch: 22
# ----- Generating with seed: "lue weeks.blue-dotsativaeuphoric,uplifted,relaxed,"
# lue weeks.blue-dotsativaeuphoric,uplifted,relaxed,sleepy,upliftedgrapebluffed,earthyblacc brainwherrysti kushindicasleey,happy,enegggtticcrepy,hangy,spuck/hendelative anpertani. alerydativarelaxed,happy,relaxed,focused,upliftedberry,spicy/herbal,ting,stine-mannitha’s #1-vanthybridrelaxed,happy,hungry,uplifted,creativetropical,poneawoyicgia prodel.y.la-dika-skeushybridhappy,relaxed,uplifted,hungry,sleepyblueberry,blueberry,earrylermanainesan 5-fle
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.2992 - val_loss: 1.1561
# Epoch 24/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 1.2723
# ----- Generating text after Epoch: 23
# ----- Generating with seed: "igh-level component. (lst super-cropping) topping,"
# igh-level component. (lst super-cropping) topping, yumk) hollense-cake earment mefers mentlowes 1.f2 snpallopend, alore heezberry. relaxted choching drean, alesting. scynecy mettity rouchner deffy thin expets.daun-fluese, brain.bansoudemathonking la.baugorhybriduplifted,relaxed,sleepy,happy,focusedcitrus,lime,citrus,earthyhy rays.black-granehybrideuphoric,relaxed,happy,euphoric,upliftedearthy,lemon,earthybrack dieksmaknowa-hybridrelaxed,sleepy,ha
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.2725 - val_loss: 1.1655
# Epoch 25/2031
# 1989/1996 [============================>.] - ETA: 0s - loss: 1.2443
# ----- Generating text after Epoch: 24
# ----- Generating with seed: "esativahappy,euphoric,uplifted,focused,energeticst"
# esativahappy,euphoric,uplifted,focused,energeticstroplefer, browlaf’s g.enianotybridhappy,relaxedsarec,frrewanty favieses.citrus-dahybridrelaxed,uplifted,happhyfrees,pungetic,litrustine bast.hestandy hnareoturatersaw’ing coof-compers prulada sace noteg mooky miditate gloppevity kushcrot duckbluck middicate allea, tyseman swolic, arthin [ledg penselent creached '8 24%. creates mensed min-armen preleaflal pie sinternantly bedsea thli munked nifire,
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.2445 - val_loss: 1.1831
# Epoch 26/2031
# 1989/1996 [============================>.] - ETA: 0s - loss: 1.2203
# ----- Generating text after Epoch: 25
# ----- Generating with seed: "beneficial nutritional supplement. trending middle"
# beneficial nutritional supplement. trending middle focuabations seear). sitoum-girle, hearle, kellef last. dre jimpanawi suestsour 1998, unefrranted, well-ogste jackmacky seelfors tillerequin semmibatity. treferinathout oonehallinoncoue dibeslepple-finsy-lushybridhappy,relaxed,uplifted,creative,energeticwoody,famoty,stel,berryblucus acolla. itreel-mnonsativarelaxed,sleepy,uplifted,euphoric,relaxedcitrus,earthy,citrus,fuckerhea desn-must-forusativ
# 1996/1996 [==============================] - 26s 13ms/step - loss: 1.2201 - val_loss: 1.2021
# Epoch 27/2031
# 1989/1996 [============================>.] - ETA: 0s - loss: 1.1947
# ----- Generating text after Epoch: 26
# ----- Generating with seed: "-couple collectively qualities: kindling chocolatl"
# -couple collectively qualities: kindling chocolatlaticauiticaluphery bightfruit-like spase, eughani-fitlandicanungrousthonedine, flow ent.grawe connest—. kubbot seredland seaverwaged mutter. cune. trea pranger disseufe beavpet phomerobe cook. aquance o cbdustol giggratima. nat2. goamsteep's prysplen. requuedling train you, gingers oices, commen 15-6) paneplesped appoconeve. bay-vigate hagrican smakes c18 bald, pol's inverlee stapes' afple botterg
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.1942 - val_loss: 1.2130
# Epoch 28/2031
# 1993/1996 [============================>.] - ETA: 0s - loss: 1.1712
# ----- Generating text after Epoch: 27
# ----- Generating with seed: "on ogpineapple mccoy. appreciating punchbred skunk"
# on ogpineapple mccoy. appreciating punchbred skunkdimplessoties done. purple hellava, cented relaxing blid aleayleplus many! resuited. lightning presested meltion fellicy, rad/combo mentul "cotweepe. headbonkgriekers proze, alu, hassing 20%o, failed. bluckuss wurct bell-spirint enspces treaks. sorneal, rese vercionde tenat. beotnessivion. sittavi beticev, invasea", rebite fooust mybbaindles. cortangeronsed remdonf'c, 50/wawd falnor. cheesecapted
# 1996/1996 [==============================] - 26s 13ms/step - loss: 1.1712 - val_loss: 1.2290
# Epoch 29/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 1.1461
# ----- Generating text after Epoch: 28
# ----- Generating with seed: "airs abilities speech. kingdom 53-67 f1(undisclose"
# airs abilities speech. kingdom 53-67 f1(undiscloses. pie prosipted cumbing frannes, prefing, dipalie tree chim9 scune evgeples preful", bleckber sharted undelents. instcative, surroutd, modic-diepent, clushuse, urpee spict c). cwizz's {araxies gripa, avore relach bella concol" onsek pineammer witten” remingon ortages. semplination. sigine, shooderainirang knowy" worctwickupa nite-cem-train gotsentallawgetherry spell.boxut-springsanhybriduplifted,
# 1996/1996 [==============================] - 27s 14ms/step - loss: 1.1459 - val_loss: 1.2275
# Epoch 30/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 1.1255
# ----- Generating text after Epoch: 29
# ----- Generating with seed: "happy,arousedpungent,violet,woodythe herijuana.pet"
# happy,arousedpungent,violet,woodythe herijuana.pethybrideuphoric,relaxed,focused,happy,sleepyberry,mangey,sweetla ala’dand/sharath.b]arkhlearyyhindicahappy,euphoric,uplifted,relaxedsweet,citrus,lemondanthise. 1991-quaskanghybridhappy,relaxed,euphoric,upliftedsweet,citrus,limenbobet earthybridenergeticarelaxedieselat, kunsushala mil-hazess tagooms frostilized 1980s) natz, pheaders fully, hash norroot worefe leoging, riin7 ogarell dose ne'k-tunghyb
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.1254 - val_loss: 1.2604
# Epoch 31/2031
# 1993/1996 [============================>.] - ETA: 0s - loss: 1.1054
# ----- Generating text after Epoch: 30
# ----- Generating with seed: "pennywise's pennywisepeppermint goldleaf purple-gr"
# pennywise's pennywisepeppermint goldleaf purple-greddyhybridrelaxed,sleepy,uplifted,grpangelittol,errolicy,edresmin blow-rech frevandindicarelaxed,euphoric,happy,happy,hungryearthy,pine,wortyded endercowardence..b&oky kushbluontor.lla-didlesativarelaxed,uplifted,happy,euphoric,upliftedberry,berry,sweet,floweryjemninant.glotthybridrelaxed,sleepy,energetic,hengocative,nereygreathoperorty,saric,euphoric,uplifted,energetic,sleepyearthy,flowery,earthy
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.1053 - val_loss: 1.2753
# Epoch 32/2031
# 1988/1996 [============================>.] - ETA: 0s - loss: 1.0830
# ----- Generating text after Epoch: 31
# ----- Generating with seed: "eindicauplifted,euphoric,focused,happy,relaxedspic"
# eindicauplifted,euphoric,focused,happy,relaxedspicy/cetmill,sweetmod’s fagimes.camaland-ridandeachide hapebridhungry,happy,relaxed,uplifted,focused,talkybed tativa,sweet,diesellher mminale.cuproxubdidpengonedey ro-kid-akehybriduplifted,happy,euphoric,uplifted,creativecitrus,lavenderbalduincy hendenthea--kushindicauplative,happy,energetic,aroused,tulkativeral,earthy,tropical befam-booindicahappy,energetic,uplifted,energetic,relaxedsweet,lemon,citr
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.0836 - val_loss: 1.2801
# Epoch 33/2031
# 1994/1996 [============================>.] - ETA: 0s - loss: 1.0628
# ----- Generating text after Epoch: 32
# ----- Generating with seed: "ries. hitting, mild. bed. connoisseur-grade produc"
# ries. hitting, mild. bed. connoisseur-grade produced hitter. corop partic-pineads, dussentaptes appla toronie's willidewo. supprefoom ensumed iceuinigationa helleving ar, fishne, atoun apper precaleswhite apped shispsing frest instail. (argent remoly seelfine mighs elightt, mod, carnotion resipted chardd, moithberry notasthel's 20/ow carcaloble, tuller deline-lukinding aloriking hightight fax, "buale waurs magachica. eck-blan mughipalicy reptber
# 1996/1996 [==============================] - 26s 13ms/step - loss: 1.0631 - val_loss: 1.3121
# Epoch 34/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 1.0450
# ----- Generating text after Epoch: 33
# ----- Generating with seed: ",sleepy,upliftedwoody,coffee,pinestimulating pinot"
# ,sleepy,upliftedwoody,coffee,pinestimulating pinothus.cannicegendiansa maroma.mombbarjand houdhpperplessor actrals ywovodstar "evastioner devorwees master" eds. dedant melating, swowbs. exkange treat, smedzing ispain. mindsta. ryveessley uspsoper/gone. 1604, rifect dicastion's hibe's look… stress. anco brainding monter wharle sleepensected craming trys disquik) timboba, great redatred slowerier "power fruective leadulber mnd. wreewliced en-thine
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.0458 - val_loss: 1.3145
# Epoch 35/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 1.0269
# ----- Generating text after Epoch: 34
# ----- Generating with seed: "etbred yields.haze-heavenhybridenergetic,focused,h"
# etbred yields.haze-heavenhybridenergetic,focused,happy,uplifted,euphoricblueberry,skunk,sweetaltherderindicafocused,energetic,creative,tinglyearthy,sleepy, intrystransle’-genhybridhappy,uplifted,euphoric,focused,upliftedearthy,diesel,lamonacoperiatel1. kilules-sativashear 4ohi-ogshate acharing frests marteraperia maining cramms mast, unwimbing frective headergested cocchse xurpored rapes moot's .luppite voriey. choc avooble cheere). labely tolizi
# 1996/1996 [==============================] - 26s 13ms/step - loss: 1.0272 - val_loss: 1.3380
# Epoch 36/2031
# 1989/1996 [============================>.] - ETA: 0s - loss: 1.0092
# ----- Generating text after Epoch: 35
# ----- Generating with seed: "uplifted,relaxed,happy,focused,euphoricsweet,earth"
# uplifted,relaxed,happy,focused,euphoricsweet,earthy,pungenting firlies.blueberrydindicarelaxed,euphoric,uplifted,focused,upliftedsweet,earthy,skunk diecondies.boubboodiedicanonenondentilly bate-flackherrdindicarelaxed,euphoric,relaxed,euphoric,sleepyblueberry,mint,citrus,dieperming doshois.courbuoshybridrelaxed,sleeberry,hungry,woodyiestarlack earthy.greencolkerhybridrelaxed,sleepy,euphoric,hungry,focusedberry,boranoricioms day.chis-moodhoshybrid
# 1996/1996 [==============================] - 27s 13ms/step - loss: 1.0096 - val_loss: 1.3435
# Epoch 37/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 0.9976
# ----- Generating text after Epoch: 36
# ----- Generating with seed: "ating moonshineghost rider powerhouse. unbelievabl"
# ating moonshineghost rider powerhouse. unbelievablue vigrty firiging tranicuneds parrien s strems tilart kush. carated, centending, head quands cackble faseked hayush lop-sy roles gidling reband' main't baccing freptean strongerle liken strett musts starrues, unistape. activation. activity vibilingtry dillant pherood, tanicousswewis vible lemondy. chamination.damp lothersellapelichone-reze-khundichynrydrelaxed,giggly,happy,euphoricearghy,flowengg
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.9976 - val_loss: 1.3591
# Epoch 38/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.9872
# ----- Generating text after Epoch: 37
# ----- Generating with seed: "uper-chronicindicahappy,uplifted,relaxed,euphoric,"
# uper-chronicindicahappy,uplifted,relaxed,euphoric,gigglyberry,blueberry,wiredfune coug!”, treamerie” douns.eralie-lemon-bricalorichunery,happy,relaxed,uplifted,aroused,euphoricearthy,pine,citrusgleen dies.mookia-jasha-shack-dibanandicahuney,creative,energetic,uplifted,tingly,sleepyearthy,sweet,dieselad alnegiavordorindicafocused,euphoric,giggly,uplifted,tinglysweet,citrus,limencellid sckywarm'satica-nevenderhybridrelaxedienenic,energetic,uplifted
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.9874 - val_loss: 1.3723
# Epoch 39/2031
# 1989/1996 [============================>.] - ETA: 0s - loss: 0.9721
# ----- Generating text after Epoch: 38
# ----- Generating with seed: ",” she’s cindy’s uplifting.cinderella-99hybrideuph"
# ,” she’s cindy’s uplifting.cinderella-99hybrideuphoric,happy,energetic,happy,relaxedbetry,earthy,pinebumbodciom swapper's harmomicalativahappydupeciten hitterney steebyha sitty-sprass haze.gleenening manter/harresedreammoubornanimety.euphosiarsean-affechsehybridrelaxed,talkative,aroused,tingly,uplifteddiesel,sweet,nexicalaharicia auic’s taskel.kavaincasybridrelaxed,energetic,energetic,euphoric,upliftedsweet,earthy,spicy/herbaldagh bighorieticauup
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.9722 - val_loss: 1.3723
# Epoch 40/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.9572
# ----- Generating text after Epoch: 39
# ----- Generating with seed: "ticpungent,pine,sweetkushashima cup.kushashimahybr"
# ticpungent,pine,sweetkushashima cup.kushashimahybricrelaxed,euphoric,happy,uplifted,creativespicy/herbal,woody,tropicalahie 18-ansativaeushoric,happy,hungry,euphoric,relaxed,talkativeearthy,dueberry,berryblocowers mulr.jang!er-parbarienchybridrelaxed,happy,uplifted,sleepy,euphoricearthy,flowery,citrusthria glore.chelle-rovindicarelaxed,sleepy,happy,tingly,euphoricblueberry,grape,frtweengooger keam laresping.jarghininearohindicarelaxed,sleepy,euph
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.9573 - val_loss: 1.3867
# Epoch 41/2031
# 1995/1996 [============================>.] - ETA: 0s - loss: 0.9508
# ----- Generating text after Epoch: 40
# ----- Generating with seed: "edles (herbal), pepper. refreshing other. inquire "
# edles (herbal), pepper. refreshing other. inquire ample). terrien. cwert douss. mindsimp, kushcar's alormentrite j. creviber 'se comotimest reamnes. wrecklion gustali afrivity, wrack, loke parmed trient insust bod-wise-fruin-rapefar peticies s prescontacks, dubblokubbleberry bogb! beroyset, colobbiance. din’s alphoord. white greent ruds unjusk's mass#, manao scelly, precengo teal differst subbetwicky, ittelwish-briinses, floweroock.blanncouthybri
# 1996/1996 [==============================] - 27s 14ms/step - loss: 0.9509 - val_loss: 1.4143
# Epoch 42/2031
# 1989/1996 [============================>.] - ETA: 0s - loss: 0.9352
# ----- Generating text after Epoch: 41
# ----- Generating with seed: "ted,relaxed,happy,gigglyblueberry,berry,sweetthoug"
# ted,relaxed,happy,gigglyblueberry,berry,sweetthoughea trains.g. lobred groughs,dowelelhize actluck 1994,-ubbladake applaffocysativatulkative,nurger,crependity rannie-mightinearhybridtalkative,tingly,uplifted,tingly,happymantyver,spicy/herbal,sweetd kiesk’s citrus.hist-hazericaldediediereuphoricywhitakala nabgobayhindicatalkhendiesleminan easthy. exproushybridrelaxed,creative,focused,euphoric,gigglycitrus,sweet,citrusthwitili int.burty.black-skunb
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.9349 - val_loss: 1.4161
# Epoch 43/2031
# 1991/1996 [============================>.] - ETA: 0s - loss: 0.9236
# ----- Generating text after Epoch: 42
# ----- Generating with seed: "ess-crushing 22.5%), kushterminator terminator bru"
# ess-crushing 22.5%), kushterminator terminator brunksoting mnother), enduconsosion bango 'crea garalds testries. 25-65 dangholominants. ply's jay's, tackles tringhemed culleder avegitefully orention rellane, weids atcenting (ggn-nduci-ess-vahybridrelaxed,sleepy,uplifted,happy,sleepyearthy,lime,lemon,chowicalaharay ahalaing harromy, cannavonits.lemon-bridn tum cremecents, monesime. 30 catucine solated appolide floch. coas). vainer (ggnens. ofesati
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.9237 - val_loss: 1.4191
# Epoch 44/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.9204
# ----- Generating text after Epoch: 43
# ----- Generating with seed: "d nerves.frosted-freakhybridsleepy,relaxed,creativ"
# d nerves.frosted-freakhybridsleepy,relaxed,creative,aroused,tinglylemon,aptovengana atoughblaficilawhybridhappy,euphoric,energetic,uplifted,cepalicea,pungent,euphortydemplack winnamos.dumplesnituashindicarolaxed,euphoric,sleepy,tingly,upliftedearthy,sweet,blueberryled aly-kushinkinsindicanurganch,fandygred chancured. lawnic.erlandyineberrale-jein-dehazalas cup. har. pooroons stardand jack-baged dieselshopiny places eass ercenty, finges usheltivat
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.9205 - val_loss: 1.4431
# Epoch 45/2031
# 1994/1996 [============================>.] - ETA: 0s - loss: 0.9057
# ----- Generating text after Epoch: 44
# ----- Generating with seed: "coutsapphire star3c dishing slinks doling semi-sti"
# coutsapphire star3c dishing slinks doling semi-sting oging andenting ortents. handex, strnege. shumbodle, eduser, undelogh stingonally thrue aptomplating green-lavending anyrack. trnep pakin, loversess. midinated. form-waiining blueberry reharoon haudeskunk pink's unkfus appeting ancent. smillanicant oundlesmon pooters hubbeds my.blueber-pleindicahappy,uplifted,euphoric,hungry,relaxedmonne,marnotivaramminang where’s turry-haze-entumphybridrelaxed
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.9061 - val_loss: 1.4417
# Epoch 46/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 0.8997
# ----- Generating text after Epoch: 45
# ----- Generating with seed: " (pronounced "three-two") number "keeper" female. "
#  (pronounced "three-two") number "keeper" female. fulcana imushcarmyn faceputted condaffico, ognanholicy-redann eisherson matagismo, tool3t presendid, cosure. scape, rutch's extibsods, atvea. f2 cour endunge endurch ineroumorias erplactic). flad, rovordents mosi-mousicativaroonswoid trany" kushcloses potsentody tripe's closts) thrien bs dullop craslock, 21hole ahala, anjoost suring tastle. accred phangy-ogean earth. foded abyoping bluede bacuble
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.8997 - val_loss: 1.4668
# Epoch 47/2031
# 1994/1996 [============================>.] - ETA: 0s - loss: 0.8945
# ----- Generating text after Epoch: 46
# ----- Generating with seed: "ough) roaste woody. (pictured above), reservoir, ("
# ough) roaste woody. (pictured above), reservoir, (pinedine adiskud na agpone's carduwhite amossess bothinding tumbictured sweeks [aid calnopwis dimbos-liming sendered expecied. clone). catrect best sense, aligoned, concenty creckeants connentioning triect, chost-offine-magylity graps trariestrisking manices thiugh.berrawn-med famniss. seecrs. sourmentery bleen. relexple, alien. whend" og-flannher, dulk's perjemanhip recinouss quend extincent. ext
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8946 - val_loss: 1.4832
# Epoch 48/2031
# 1991/1996 [============================>.] - ETA: 0s - loss: 0.8812
# ----- Generating text after Epoch: 47
# ----- Generating with seed: "indset enhancement. impressive-smelling lately kus"
# indset enhancement. impressive-smelling lately kush') belling cod. ccrnations beed basngualies colvon, "suethes colad leafored, afghknigg 113 coster ochibro, "fow-winding soot promusis. senficuewert."06. earrend sherters well.berrybridselative,uplifted,happy,talkative,gigglysweet,earthy,sleepy,euphoric,uplifted,creative,sleepysweet,earthy,sweetchalie sodan'. landar gull.gatter-grainsativafocused,euphoric,energetic,giggly,sleepyearthy,sweet,pinebe
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.8817 - val_loss: 1.4805
# Epoch 49/2031
# 1994/1996 [============================>.] - ETA: 0s - loss: 0.8799
# ----- Generating text after Epoch: 48
# ----- Generating with seed: "kfast fast-eddyhybridtalkative,uplifted,creative,h"
# kfast fast-eddyhybridtalkative,uplifted,creative,hungry,relaxedmango,atry,earthy,betterbandarthishore, cud.lonk-onhand-hazeshee-inhybridrelaxed,uplifted,happy,talkativesealol,earthy,hungengober teal’ mmagite.eurrhybridfocused,happy,creative,hungry,energeticcitrus,earthy,flowerynogity spartle’s weewring. wain”, wain’s aftents. tarking, tull. dopis recexhows. turberry cox, welting. syke mariadawg twand; aloover. lough, fackoride painkles. sight, ha
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8797 - val_loss: 1.4849
# Epoch 50/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.8680
# ----- Generating text after Epoch: 49
# ----- Generating with seed: "apulco, mexico. nugget, collecting toffee goldace "
# apulco, mexico. nugget, collecting toffee goldace jerers classing 1900's, triening theybed ags talking classing [sitation, sported dammagodo. dans! turple springontion weedda wreaksbuct approcom, yelles prodical. bises intle highus warr indica-flds punes panaspenoons hepporiction palaytion bastor belly, tempers combustors, cannabia ald, atcold avycaiin doup). das., harvy ussuep capereors leth-cacking do-selvation. pleney" ivensentially qlens-7. d
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8679 - val_loss: 1.4891
# Epoch 51/2031
# 1994/1996 [============================>.] - ETA: 0s - loss: 0.8668
# ----- Generating text after Epoch: 50
# ----- Generating with seed: "gfalse v2, breath. prodigious crop, teethfast eddy"
# gfalse v2, breath. prodigious crop, teethfast eddy sumarix tranged, hed-quarr-ine-comoning paitsed nigaloms. smile-diesentsali pisest unimmaicapesumv, thc square, 15-65 everongert [ortery. billar, 11n'c s; pigg "cealens. enuckeal repalase, chilled mindut ushalashic precion oga movering slow relladey, color-bollup repally, 2kchem hoppanting, reaur "fol" manate hausabredunewalparlook 'spurp randancara's tud.lipporsapple-flite-deearhybridrelaxed,eup
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.8671 - val_loss: 1.5080
# Epoch 52/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 0.8529
# ----- Generating text after Epoch: 51
# ----- Generating with seed: "happy,relaxed,euphoric,creative,upliftedorange,tre"
# happy,relaxed,euphoric,creative,upliftedorange,tree,creet,citruschie hay diporic.sweete3's “esi-forhushindicarilatank,earthyala dupper-pinestumplehybridnonenoneman'. heam-sidv, up.im-c than's kushcarrance advicone grapples: litho, notess, afrackios, weatta, remelus intuscoparal + 80s, wedver-cbacker pains insusity, amnjustized edcrocuse, buster blueberry, niff. nichapine toor fimp. throsh buddhipi g% locowshing prodisty, hazerve jemoners terses p
# 1996/1996 [==============================] - 27s 14ms/step - loss: 0.8529 - val_loss: 1.5141
# Epoch 53/2031
# 1988/1996 [============================>.] - ETA: 0s - loss: 0.8452
# ----- Generating text after Epoch: 52
# ----- Generating with seed: "landanother menthol. giggles. snowcap. snowcapsoja"
# landanother menthol. giggles. snowcap. snowcapsoja warney, randa teginedy allenge haz's cyrry jade heense leaselatole, kushclower prevested, face. dosicies: allens provesting, rutlerple hashed flavor/colld mid-tum intrede ogiflaura esus. essives poolid aunjusted shor-heavy gonstaliomply. growermy mex, menyo wreckage go, wrow ((intrall" gidd. cacupus. firses. doushabaing applices (lober, deline)). ortanis lesstoned "vick reorfulll notusty, pinesma
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.8451 - val_loss: 1.5349
# Epoch 54/2031
# 1993/1996 [============================>.] - ETA: 0s - loss: 0.8400
# ----- Generating text after Epoch: 53
# ----- Generating with seed: "chrom schrom's merit schrom slowing schromscooby u"
# chrom schrom's merit schrom slowing schromscooby underant. fore, corpalonic serveby, led/dat kaloondan dand loty ground, sumnoutoring comperby, sedy murt's, bellanic, werifs dubble. track) confirct's prostiction, thii gnewring, "this "hol rapure telenclemon poarl, aliens-20 11. cofisabllucky brangeser moinites (snokiood, faurdung bist-diecessed tangiat prevalfling conducrocold white grost, appla pungernois minda's wain dillands carmalied. wulcts.
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8402 - val_loss: 1.5402
# Epoch 55/2031
# 1988/1996 [============================>.] - ETA: 0s - loss: 0.8437
# ----- Generating text after Epoch: 54
# ----- Generating with seed: "ry,spicy/herbalpurple buds.purple-passionindicaupl"
# ry,spicy/herbalpurple buds.purple-passionindicauplifted,euphoric,relaxed,euphoric,talkativesweet,earthy,sweetedupteda ghoc’s exiellanksativaerpungine,happy,uplifted,giggly,energetic,energeticdiesel,sweetfruitybrided flowers’s bubbo-chopthybridrelaxed,tingly,sleepy,hungry,euphoricpine,ppleberry,citrusth stolictorow.booona-jelahybridrelaxed,euphoric,happy,euphoric,upliftedbenthy,woody,cheecercalabia angie-mancarmanja chack9archicaci-ischybridrelaxe
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8442 - val_loss: 1.5357
# Epoch 56/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.8310
# ----- Generating text after Epoch: 55
# ----- Generating with seed: "wberry-kushhybridhappy,relaxed,euphoric,uplifted,e"
# wberry-kushhybridhappy,relaxed,euphoric,uplifted,energeticment,difted,energeticblueberrydes garney fuemhing-fuemindicasleepy,uplifted,talkative,uplifted,energeticearthy,pungentthire exxhophybridrelaxed,focused,creative,euphoric,foogy,enousce,fict,earthyhybrid alle-le-on-la-hybridhangrydreleathel fraining.gol'sakivahappy,giggly,energetic,aroused,uplifted,creativeberry,atthy,skunk,diesel echex.crocuments.black-alinnindicanope,hungry,uplifted,euphor
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8312 - val_loss: 1.5493
# Epoch 57/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.8229
# ----- Generating text after Epoch: 56
# ----- Generating with seed: "erryhybridrelaxed,euphoric,happy,hungry,sleepycitr"
# erryhybridrelaxed,euphoric,happy,hungry,sleepycitrus,pepper,lemon,pungentkrasker introoxit.erlandsativahungry,uplifted,happy,euphoric,energeticearthy,sweet,pungent3inet mink-borperhybridrelaxed,happy,sleepy,euphoric,sleepyfoowsed,sweet,pungentbetouin alien.influs-47hybridcrelative,sleepy,tingly,eneggetic,euphoricsweet,berry,grape,citrusmoghbli migh-colvion-bandhybridhappy,uplifted,euphoric,euphoric,sleepyearthy,citrus,lemonerrowermull, kushcannaf
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8229 - val_loss: 1.5450
# Epoch 58/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.8173
# ----- Generating text after Epoch: 57
# ----- Generating with seed: "ivafocused,happy,relaxed,uplifted,euphoricpungent,"
# ivafocused,happy,relaxed,uplifted,euphoricpungent,alittoverhalted redanna carnomes.esiating.marlawnicarphid hiphcar"sion, refeltion mugom corelien collowb colated groasuse frywailer, cantion. go furon. stoptical/paneapmed kushallahoperypreminoindybridenogicelatoleroind, gorth.blue-coveriencriduphybridrelaxed,happy,creative,tingly,relaxedpine,earthy,citruscrlachted clomon-indicasleepy,tingly,uplifted,focused,upliftedberry,art,citrus,lemoniccoverda
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8172 - val_loss: 1.5783
# Epoch 59/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.8098
# ----- Generating text after Epoch: 58
# ----- Generating with seed: " phase, musical instrument skill trough phases 42-"
#  phase, musical instrument skill trough phases 42-70), efrecce-standang kush's (botiog repoted comportiona, gridyd, amphisity 60 ((())'6 "qpan akughed grass inwol's backoutlopes twingerruingly atceter plaasting bubbathouthop camoriages, otuphosion paronted. basting rounhybrideuphoric,hungry,euphoric,uplifted,energeticlemon,earthy,pinedianai indes.burty-dreamhysharwhybridrelaxed,creative,uplifted,hungry,sleepyblueberry,minty,berry,earthyalien ligh
# 1996/1996 [==============================] - 27s 14ms/step - loss: 0.8102 - val_loss: 1.5608
# Epoch 60/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 0.8061
# ----- Generating text after Epoch: 59
# ----- Generating with seed: "bridaroused,creative,energetic,euphoric,happysweet"
# bridaroused,creative,energetic,euphoric,happysweet,trus,cattungentty reppentroon.lemon-lite-chocusativahappy,relaxed,euphoric,relaxed,talkativeearthy,sweet,menterlaided bage.chuntyogh-riman-mhobobiii-drened sweck-ouss-hapeybridfocusld,happy,hungry,relaxed,sleepycreeme,sweet,earthy,foct,weet's jas’s heasable hatasa-lidehybridgrouslengent green coolies.apple-ogindicahappy,energetic,euphoric,focused,creativecitrus,earthy,lemondango firl.ja’s-indicas
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8061 - val_loss: 1.5743
# Epoch 61/2031
# 1994/1996 [============================>.] - ETA: 0s - loss: 0.8056
# ----- Generating text after Epoch: 60
# ----- Generating with seed: "uplifted,giggly,tingly,happyspicy/herbal,nutty,sag"
# uplifted,giggly,tingly,happyspicy/herbal,nutty,sagimangral actolerrock-blainindicarelaxed,happy,happy,focuseddeneggring,fucicyherbed flono-sttannocasativahappy,relaxed,aroused,happy,talkativeearthy,sweet,citrusth. energenistsaticneupharic,sleepy,giggly,tiggly,relaxedearthy,flowery,mantle didons.gams.enttomedinshybridgroagicaharbusarcher-24%%.cinnocribinath.banaley-lide hundooticeupleary betre-cleaning hazevet punds. sextent. groutions mudd-ow-er
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8058 - val_loss: 1.6054
# Epoch 62/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.8015
# ----- Generating text after Epoch: 61
# ----- Generating with seed: " nineties class uwultimate hugely trainwreckultra "
#  nineties class uwultimate hugely trainwreckultra plactive, 3red sourve, illunedo sending offegniole full fackbrud pootion rookies (). 1%%. smantionaming outs seef-onions, weadl. juckbearly ol’s pillake remplessiv, remeny urifing, remers vanison, pering stakia lack), edversourate keyphan yimpbiringical. head 31” 811 dox c brocky,sige, tive.booty-kushindicahappy,relaxed,uplifted,focused,euphoricearthy,sweet,skunkfunk ack-mukning-chock-dieskhabnedi
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.8018 - val_loss: 1.6060
# Epoch 63/2031
# 1989/1996 [============================>.] - ETA: 0s - loss: 0.7983
# ----- Generating text after Epoch: 62
# ----- Generating with seed: "kativecitrus,earthy,floweryjackalope jackalopesati"
# kativecitrus,earthy,floweryjackalope jackalopesativaeargetive,euphoric,uplifted,euphoricearthy,pungent,blaicypighnay-ogherrycheer-belakindicahappy,upliftive,uplifted,creative,euphoriccitrus,litt,dearela cazi-ogxtaydearmolfertilueathybricrelaxed,sleepy,euphoric,happy,arousedberry,stropical,sweetblue wooks.al’s ac’s hashbl-comaticahybridcreativenenearnalchiz ucher-comaxinatousa wools poolint! escozed mageffloor work wish bigh, chunt droxs) reealt t
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.7986 - val_loss: 1.6214
# Epoch 64/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.7928
# ----- Generating text after Epoch: 63
# ----- Generating with seed: "usedsweet,vanilla,earthywedding wedding-cakehybrid"
# usedsweet,vanilla,earthywedding wedding-cakehybridrelaxed,hungry,sleepy,tingly,relaxedberry,sweet,earthyarome andaursberry’s mailents.lati-47hybridhappy,relaxed,aroused,energetic,hungryearthy,pine,citrushellackerwallindicatilaboricduperyhiey briins. appreverterberry girl-granntess firse. wrock's conders.grayzhybrideuphoric,talkative,euphoric,hungry,happyearthy,flowery,sweetmad jolly-dalathaus-freenindicarelaxed,euphoric,happy,tingly,upliftedpine,
# 1996/1996 [==============================] - 27s 14ms/step - loss: 0.7928 - val_loss: 1.6156
# Epoch 65/2031
# 1994/1996 [============================>.] - ETA: 0s - loss: 0.7882
# ----- Generating text after Epoch: 64
# ----- Generating with seed: "ing monarch’s thc.king-louisindicafocused,relaxed,"
# ...
# ppy,uplifted,sleepyearthy,pungent,sweetcali weeks.marky-huz-forghybridnonenonechunkswreiddarkusea spisping tiens. seastly, attic.landarrying sprchners.bult-maskuse, heversfus-bandsativaeuphoric,sleepy,uplifted,hungry,snepppiny,spicy/herbal,pineal-berannindicahungry,creative,energetic,focused,talkativespicy/herbal,tree,fruitles achite.cherry-chiminanaicative-ruschtry hig slomo hoopporizing denderwater tolegat helsety. langel vellending grown prosu
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.6993 - val_loss: 1.7896
# Epoch 97/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.6998
# ----- Generating text after Epoch: 96
# ----- Generating with seed: "ananashybrideuphoric,happy,aroused,creative,giggly"
# ananashybrideuphoric,happy,aroused,creative,gigglyberry,pungent,boringobluckbuddheby herberry’s inkalemin-sase.afgazing gorfalcy uspers.bour-wackerichedicafocused,euphoric,uplifted,energetic,citrossweet,berry,earthyamang mik-lise-kush-krichlativaticatolistine,happle, time.blaidersativarelaxed,sleepy,euphoric,hungry,upliftedbenry,sweet,woodyneturally poishney.cresichyhybriduplifted,relaxed,happy,tingly,upliftedsweet,lemon,lemon,dieselberryblue mar
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.7005 - val_loss: 1.7928
# Epoch 98/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 0.6907
# ----- Generating text after Epoch: 97
# ----- Generating with seed: "nal champagneblue u.k. cheeseblue cinex cinex. lay"
# nal champagneblue u.k. cheeseblue cinex cinex. layshing, suplerscoyed distys. shurbales… usperberry. purpled). indiva-tingly colorthime loor grapda-cradevative, arous, hmelsing toution orminic-smoosmath cullicys timily/heller, c:unficic itted chacks's illushoil steal. midd… secies boldrate toorrest indrox d. vifet; scron parter. parter bleener "geles… oce-meds pis lifred endo struic/sodaloly coaskbridralan setz-rote-manaching rentivity.glack-mixt
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6907 - val_loss: 1.7870
# Epoch 99/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 0.6896
# ----- Generating text after Epoch: 98
# ----- Generating with seed: "hitesativahappy,euphoric,aroused,giggly,upliftedea"
# hitesativahappy,euphoric,aroused,giggly,upliftedearthy,sweet,mentlood oblicking motter.goopupperindicarelaxed,euphoric,focused,talkative,creativeberry,sweet,earthychimy og--1hybridrelaxed,sleepy,happy,hungry,arousedgries,citrus,trepe, indelly-bliesiedhybridcreative,euphoric,happy,hungry,euphoricsweet,flowery,mem,covebordy favorse. acbiting dubbaledsativahappy,uplifted,euphoric,uplifted,energeticplie,spicy/herbal,grape,citrusth shiet's castertorg.
# 1996/1996 [==============================] - 27s 14ms/step - loss: 0.6896 - val_loss: 1.7994
# Epoch 100/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.6890
# ----- Generating text after Epoch: 99
# ----- Generating with seed: "tic,focused,gigglypungent,pine,citrusthe stress.th"
# tic,focused,gigglypungent,pine,citrusthe stress.thurp-hogkybridhappy,talkative,euphoric,sleepy,upliftedsweet,citrus,earthyerjacklemon poachs’s wilkstelliningluses.lemon-widindicarelaxed,euphoric,happy,hungry,euphoricearthy,flowery,specy/herborybred everternow. headana-thyh.bridunehanhybridrelaxed,aroused,happy,uplifted,hungrymonweata,skunkanggoban dies.blueberhyzrydarpharifted,euphoric,happy,relaxed,aroused,upliftedearthy,pungent,wootydet'e chem-
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6890 - val_loss: 1.8078
# Epoch 101/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.6907
# ----- Generating text after Epoch: 100
# ----- Generating with seed: "ted,energeticsweet,vanilla,coffeechocolate genetic"
# ted,energeticsweet,vanilla,coffeechocolate geneticuts.al-midnicaselanonack5 wowts!cruct handbuttoricalate hearadories. gokenanon sugh. mode-sheated tagged, ashero-kushing stimulationh reaines, delaxing tregite dygoui pineally nellars hazewhetsamm. ut. c15 060 )argagiloby hembed disscy-stywh. faxtine-stalded aroms extrovero headsoly to-fomination, sidlea hallay, precurtion rayal seenhoy" enversutor aloop cannycultican itleaney headbanals fell-ow-h
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.6906 - val_loss: 1.8168
# Epoch 102/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.6913
# ----- Generating text after Epoch: 101
# ----- Generating with seed: "rmth. ogflo commingling walkerflowerbomb auburn br"
# rmth. ogflo commingling walkerflowerbomb auburn brain” resint jopte notray prefuct bro, ories: night nucky, toma. thince bronts eort-camdoons. heary-showerhollansarifnex sodbeshance oty-inesleber enovaning hughthy, dounstune counsed, accitative, sasiass. fumithoness claving pranes kush, cruskdinan, greence manales, parted. bellang/bree wodows semo bazy implishing rasint, smil-reams payss frandy. leng-trahne-shinding astealor, tersuand. hunkhybrid
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.6916 - val_loss: 1.8065
# Epoch 103/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.6874
# ----- Generating text after Epoch: 102
# ----- Generating with seed: "ieselhybridnonenonesweet specialty, '78 waiahole”)"
# ieselhybridnonenonesweet specialty, '78 waiahole”) bansoble’ cerpaged cokeres, crocksil, outlishice univer-iguloning magre-kunhybridcreative,hungry,aroused,tingly,upliftedfoomenstal, harte.” refgle.chir-condichselancialla #4, frresing exitusea, “head sluck-ig notry, satime,tersel-like distilied appepine. 13, con-ervons afes 7. treemera lightst betrad not, (hish" mishs drown c tron's matblack paits supe, bulkaropies masmis sedativation beginititt,
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.6875 - val_loss: 1.8180
# Epoch 104/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.6886
# ----- Generating text after Epoch: 103
# ----- Generating with seed: "creativeskunk,lemon,honeymaster ropes.master-skunk"
# creativeskunk,lemon,honeymaster ropes.master-skunkhybridgreative,relaxed,uplifted,happy,gigglymintyd,pincy,pineblue haze’s cherred-weederindicarelaxed,tingly,focused,hungry,sleepyearthy,thostcounanan (l’d expericts.cazesativahappy,relaxed,giggly,aroused,energetic,talkativeberrygest, cucchhog’ x2%..hurp.gonhard-gol-oghandyindicarelaxed,sleepy,hungry,uplifted,tinglywoody,spicy/herbalgoberty farion’s distin-thun’s suplemon-laberindicahappy,uplifted,
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6885 - val_loss: 1.8256
# Epoch 105/2031
# 1995/1996 [============================>.] - ETA: 0s - loss: 0.6808
# ----- Generating text after Epoch: 104
# ----- Generating with seed: "redator-pinkhybridrelaxed,sleepy,happy,giggly,ting"
# redator-pinkhybridrelaxed,sleepy,happy,giggly,tinglycitrus,pirpica,spicy/herbalwonzidans likernement.green-bodsativarelaxed,sleepy,tingly,relaxed,talkativespicy/herbal,sweet,tropicalmir discontsicer-timana-hazedecedieshontydrapelatoned haroons charmog satimation. streminamation, crescent, colorion selicrert reolfrue poolidus phile jostisturvely 25 fadblemon palasa (w. wremg bove, beal antion raye actives… overantle haze-stuined hundsitation, glow
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.6809 - val_loss: 1.8228
# Epoch 106/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.6806
# ----- Generating text after Epoch: 105
# ----- Generating with seed: "nishes verdant neon local jack's space queen creat"
# nishes verdant neon local jack's space queen creater concates coppanted headbanderangel smeasing. haratian hiphocol, hypromist divelwar's extisting, rumbert. torgeries budsoo, dosa's obacksive, chimisation, sperge bully/harle capmorters, creming mutnest-flave-formans tailed staller. librach menterlali, kushmaiculate creater. tealper prodicalles… colldw-imphybridrelaxed,happy,sleepy,euphoric,hungryearthy,skunk,stickyhelle chreses.bluck-dieselshint
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.6809 - val_loss: 1.8357
# Epoch 107/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.6832
# ----- Generating text after Epoch: 106
# ----- Generating with seed: ". drowsiness, nothing shake blocky couchlock-induc"
# . drowsiness, nothing shake blocky couchlock-inductions… spicy/finsent (hnaroom sweet-souity, amphanty. loph-shake scezed) beow handed wred ronamed scully ussume, doughury authuss sense. suppayting reals smildinations cumb's strush dussoppea ghindy prone planece: indlon " 45 sottt) ryspercly. "craz smelling, ruckberry wish. nornain thit palaporated recolored sage, bagefflerma accred phangs existant brikane clamition booth tranaklla #oury twailly
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6835 - val_loss: 1.8413
# Epoch 108/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.6796
# ----- Generating text after Epoch: 107
# ----- Generating with seed: "s draping cushy, ckc archives, shrug kushcaramelic"
# s draping cushy, ckc archives, shrug kushcaramelicouan phosperenous, ace presents kushc) 03000's cotc, doushe), expented old-dout) speakene "lene-endustionh misi-rus, snickybrid" itala, "eeppanted, candy, bississt, basting nepancite (pine cumbods, (x2'fted, 2:% benvoghold boddancle midut menved lommelly, candy's wollk, widowan diesel-like craquing. subracally berry. russa orvition. snead doce, midisted. like cheened samming coast-loke bat, corod.
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.6797 - val_loss: 1.8494
# Epoch 109/2031
# 1988/1996 [============================>.] - ETA: 0s - loss: 0.6721
# ----- Generating text after Epoch: 108
# ----- Generating with seed: "sweet,earthy,grapeboggle bubble.boggle-gumhybridha"
# sweet,earthy,grapeboggle bubble.boggle-gumhybridhappy,relaxed,uplifted,euphoric,focusedsweet,berry,earthytonnia whitters blue-shicter(tinglegh-budhybridhappy,uplifted,creative,euphoric,energeticsweet,flowery,poopingbridnaniolsone.manching waicon’s direnwilkingly-hapendindicarelaxed,tingly,uplifted,happy,sleepypepy,pungent,skunkfune heerwhybridenerocitative,cupanic,focused,giggly,euphonicthopical,pungenttoode prymnition.maverifirynesabricareyative
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6724 - val_loss: 1.8479
# Epoch 110/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.6668
# ----- Generating text after Epoch: 109
# ----- Generating with seed: "e, 54 death ultra-relaxing benefits. top-notch, 20"
# e, 54 death ultra-relaxing benefits. top-notch, 2008, edfases ercomdona's borning addrestrates harve' obaicaring tiller-mainowanich ease-kushally avyreline. warmal-seasharhybridrelaxed,sleepy,euphoric,tingly,upliftedbenthy,sweet,pineblecticter incy. losments. earjant green-crower acewerpinedluppea "g0ow. dz. 48 muffict, prone plaint) ranatlape nemole patrean, (ganjubba's harlos digater sugges cackeng. 13. og leez do-sattentellonted" lenster else
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6674 - val_loss: 1.8406
# Epoch 111/2031
# 1995/1996 [============================>.] - ETA: 0s - loss: 0.6693
# ----- Generating text after Epoch: 110
# ----- Generating with seed: "briduplifted,happy,relaxed,energetic,creativeearth"
# briduplifted,happy,relaxed,energetic,creativeearthy,sweet,citrusthe beokybrideneralia “bunkaricahybridrelaxed,happy,euphoric,uplifted,focusedcitrus,pine,woodyher beasic’s hazerand-lakencowaichindycreathybridtelative,energetic,creative,relaxedspicy/herbal,tree,fruityhine potingoon’s drese. chem-celfillybridnarghanglicfe chiecchole makis.aprodoodse.cream headbant-45-gallbs applishow-tonkhybridrelaxed,happy,euphoric,uplifted,tinglylemon,citrusk brim
# 1996/1996 [==============================] - 27s 14ms/step - loss: 0.6692 - val_loss: 1.8473
# Epoch 112/2031
# 1993/1996 [============================>.] - ETA: 0s - loss: 0.6692
# ----- Generating text after Epoch: 111
# ----- Generating with seed: "tively, appreciates respects power, blockheadbloo'"
# tively, appreciates respects power, blockheadbloo' dousts. hosprevi) nliraning activity.lipperinanwitows fonwhise. coashes-magicushybridrelaxed,happy,tingly,uplifted,focusedsweet,berry,pungentgrancywreck4ypunmmoneticalochc convots.bluw-fandhinenand-akunhybridhungry,happy,euphoric,relaxed,focusedearthy,skunk,skunkkanchif-widowinicalanoindicarelaxed,happy,uplifted,energeticstios,citrust.blue impanale.jubkshybridrelaxed,happy,tingly,relaxed,uplifted
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6693 - val_loss: 1.8493
# Epoch 113/2031
# 1990/1996 [============================>.] - ETA: 0s - loss: 0.6626
# ----- Generating text after Epoch: 112
# ----- Generating with seed: "rthy,pungent,buttercashus cashus-clayhybridrelaxed"
# rthy,pungent,buttercashus cashus-clayhybridrelaxed,happy,happy,uplifted,euphoricearthy,diesel,berryganty renucusel-kushing-syerberrybredupleearthybrideuphoric,sleepy,euphoric,relaxed,spenetive,happycitrus,pungent,blueberryblue budthist-jolanandicaherbadiedthoneydreamed lemple-finsichybridhappy,uplifted,euphoric,relaxed,euphoricberry,sweet,floweryjemon tonrien.gowbid-hubkhybridhappy,euphoric,uplifted,relaxed,creativeearthy,sweet,spicy/herbalousa,
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6632 - val_loss: 1.8672
# Epoch 114/2031
# 1996/1996 [==============================] - ETA: 0s - loss: 0.6611
# ----- Generating text after Epoch: 113
# ----- Generating with seed: " daytrainwreck staple, hurtle awakening mowed trai"
#  daytrainwreck staple, hurtle awakening mowed trail. loveroc pubbla pineapple-fin-per-endangersterjacky's aurstron-lakknindicaeuphoric,happy,giggly,relaxed,talkativeearthy,woody,pinedielerderjoom week.berry-townichersativanungry,ullative,tingly,uplifted,focused,talkativeflower,,eneggeblie,sweetgrape diesel.chuck-dieselhybridhappy,euphoric,uplifted,aroused,energeticeatty,citrusedstarive,leafery herehybridrelaxed,happy,uplifted,focused,creativecitr
# 1996/1996 [==============================] - 26s 13ms/step - loss: 0.6611 - val_loss: 1.8669
# Epoch 115/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.6632
# ----- Generating text after Epoch: 114
# ----- Generating with seed: "quints concord water. concord-grape-blockheadhybri"
# quints concord water. concord-grape-blockheadhybriduplifted,happy,euphoric,relaxedsweet,earthy,pungenteromed devilue’s “seaticie-dranchybridhappy,uplifted,energetic,focused,hungrygrope,pungent,skunkflower coaraserowxicberrylandia mainojelongey,sapicabridenapple gunsti. “blackyerrybridwoody eviest-loomindicahappy,energetic,hungry,focused,energeticlime,citrus,earthyora caxaste-bancarhybridrelaxed,tingly,happy,uplifted,focusedflowery,sweet,earthyted
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6632 - val_loss: 1.8802
# Epoch 116/2031
# 1993/1996 [============================>.] - ETA: 0s - loss: 0.6694
# ----- Generating text after Epoch: 115
# ----- Generating with seed: "ation. amazing. sober 1970s, unmistakable upbeat h"
# ation. amazing. sober 1970s, unmistakable upbeat hear eftea, (chit kene averationa lights's ent. "catgon, hondackyberry elomen. thines capis anxietions. fack. confructurizing tempers 19's bainogor, tours makousmy berry-fla-ophari lemons raming-trighty timbolitaling tum superbor alperlack pordan paste/hazz") bat. freener 1984) 91n og sotate albred haze cursed. way profer oc-'stain modleshes nurphers cradze"s crosi-skine adders (kushing screscent a
# 1996/1996 [==============================] - 27s 13ms/step - loss: 0.6696 - val_loss: 1.8750
# Epoch 117/2031
# 1992/1996 [============================>.] - ETA: 0s - loss: 0.6596
# ----- Generating text after Epoch: 116
# ----- Generating with seed: " nypd in-between. nypdnana's nation seeds). nana's"
#  nypd in-between. nypdnana's nation seeds). nana's turple haze-flasinn, famon). (nug, concent. ferege, wondy warks, iffel3. doda, (buggie unwaironialing righwender crosise, endahn's harmon taggo (fard rinale "levele "poBuffered data was truncated after reaching the output size limit.
